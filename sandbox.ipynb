# %%
from mosaic import Processor
from datetime import date

p = Processor(
    "username",
    "password",
    date(2020,6,1),
    date(2021,2,1),
    "cluj",
    "sample_inputs/p2_cluj.geojson",
    debug=True,
)

# %%
p.phase_1()

# %%
p.phase_2()
# Out:
# Querying products: 100%|██████████| 176/176 [00:02<00:00, 36.39 products/s]

# %%
p.phase_3()
# Out:
# [{'footprint': 'MULTIPOLYGON (((24.869986766421334 44.099770918209835, '
#                '24.936097556086395 45.08595696049961, 24.761369258516744 '
#                '45.09091842690364, 24.73193716942365 45.00469199463913, '
#                '24.68255569966869 44.8579633527463, 24.632898239827604 '
#                '44.711315523739216, 24.583364979077707 44.56459070351277, '
#                '24.534006121740727 44.4178082356255, 24.48482482727779 '
#                '44.27103924818629, 24.43594939993112 44.124251673813625, '
#                '24.431900341471486 44.11199670135499, 24.869986766421334 '
#                '44.099770918209835)))',
#   'index': 'b4dd526d-799d-4af5-9f5d-db1eb7db1a20',
#   'processinglevel': 'Level-1C',
#   'size': '195.76 MB',
#   'tileid': '34TGQ'},
#  {'footprint': 'MULTIPOLYGON (((24.869986766421334 44.099770918209835, '
#                '24.936097556086395 45.08595696049961, 24.75891597092566 '
# ...

# %%
p.phase_4()

# %%
p.phase_5()
# Out:
# Downloading:   0%|          | 0.00/783M [00:00<?, ?B/s]
# Downloading:   0%|          | 3.15M/783M [00:01<05:14, 2.48MB/s]
# Downloading:   1%|          | 5.24M/783M [00:02<05:19, 2.44MB/s][A
# Downloading:   1%|          | 9.44M/783M [00:03<05:24, 2.39MB/s][A
# Downloading:   2%|▏         | 12.6M/783M [00:05<05:13, 2.46MB/s][A
# Downloading:   2%|▏         | 15.7M/783M [00:06<05:06, 2.51MB/s][A
# Downloading:   2%|▏         | 18.9M/783M [00:07<05:14, 2.43MB/s][A
# Downloading:   3%|▎         | 22.0M/783M [00:09<05:18, 2.39MB/s][A
# Downloading:   3%|▎         | 25.2M/783M [00:10<05:36, 2.25MB/s][A
# Downloading:   3%|▎         | 26.2M/783M [00:10<05:25, 2.32MB/s][A
# Downloading:   4%|▎         | 28.3M/783M [00:12<06:57, 1.81MB/s][A
# Downloading:   4%|▍         | 30.4M/783M [00:13<05:13, 2.40MB/s][A
# Downloading:   4%|▍         | 32.5M/783M [00:14<05:34, 2.25MB/s][A
# Downloading:   4%|▍         | 34.6M/783M [00:15<05:49, 2.14MB/s]
# ...

# %%
p.phase_6()
# Out:
# Dezarhivare pitesti/S2A_MSIL1C_20200831T092031_N0209_R093_T34TGQ_20200831T110046.zip
# Dezarhivare pitesti/S2A_MSIL1C_20200831T092031_N0209_R093_T35TLK_20200831T110046.zip
# Dezarhivare pitesti/S2A_MSIL1C_20200828T090601_N0209_R050_T35TLK_20200828T103919.zip

# %%
p.phase_7()
# Out:
# Converting pitesti/S2A_MSIL1C_20200831T092031_N0209_R093_T35TLK_20200831T110046.SAFE/GRANULE/L1C_T35TLK_A027117_20200831T092344/IMG_DATA/T35TLK_20200831T092031_TCI.jp2
# Converting pitesti/S2A_MSIL1C_20200828T090601_N0209_R050_T35TLK_20200828T103919.SAFE/GRANULE/L1C_T35TLK_A027074_20200828T091337/IMG_DATA/T35TLK_20200828T090601_TCI.jp2
# Converting pitesti/S2A_MSIL1C_20200831T092031_N0209_R093_T34TGQ_20200831T110046.SAFE/GRANULE/L1C_T34TGQ_A027117_20200831T092344/IMG_DATA/T34TGQ_20200831T092031_TCI.jp2

# %%
p.phase_8()
# Out:
# {'count': 3,
#  'crs': CRS.from_epsg(32635),
#  'driver': 'GTiff',
#  'dtype': 'uint8',
#  'height': 10980,
#  'nodata': None,
#  'transform': Affine(10.0, 0.0, 300000.0,
#        0.0, -10.0, 5000040.0),
#  'width': 10980}
# {'count': 3,
#  'crs': CRS.from_epsg(32635),
#  'driver': 'GTiff',
#  'dtype': 'uint8',
#  'height': 10980,
#  'nodata': None,
#  'transform': Affine(10.0, 0.0, 300000.0,
#        0.0, -10.0, 5000040.0),
#  'width': 10980}
# {'count': 3,
#  'crs': CRS.from_epsg(32634),
#  'driver': 'GTiff',
#  'dtype': 'uint8',
#  'height': 10980,
#  'nodata': None,
#  'transform': Affine(10.0, 0.0, 699960.0,
#        0.0, -10.0, 5000040.0),
#  'width': 10980}
# {'count': 3,
#  'crs': CRS.from_epsg(32635),
#  'driver': 'GTiff',
#  'dtype': 'uint8',
#  'height': 10980,
#  'nodata': None,
#  'transform': Affine(10.0, 0.0, 300000.0,
#        0.0, -10.0, 5000040.0),
#  'width': 50976}

# %%
p.phase_9()

# %%
p.phase_10()
